# %%
from bayesian import *
from graph import *

# %%
data_num = 4

# %%
X, Y = initialize_XY(data_num)
mean, std = gpr_prediction(X,Y)
plot_prediction(mean,std,X,Y)
X_next, Y_next = ucb_proposal(mean,std)
X, Y = addition(X, Y, X_next, Y_next)
# Out:
# 2.73**2 * RBF(length_scale=1.54) + WhiteKernel(noise_level=1e-05)

# %%
X, Y = initialize_XY(data_num)
loop = 10
for i in range(loop):
    mean, std = gpr_prediction(X,Y)
    X_next, Y_next = ucb_proposal(mean,std)
    if i != loop:
        X, Y = addition(X, Y, X_next, Y_next)
plot_prediction(mean,std,X,Y)
# Out:
# 2.73**2 * RBF(length_scale=1.54) + WhiteKernel(noise_level=1e-05)
# 2.95**2 * RBF(length_scale=1.64) + WhiteKernel(noise_level=0.000139)
# 2.9**2 * RBF(length_scale=1.59) + WhiteKernel(noise_level=1e-05)
# 2.92**2 * RBF(length_scale=1.6) + WhiteKernel(noise_level=1e-05)
# 2.93**2 * RBF(length_scale=1.6) + WhiteKernel(noise_level=1e-05)
# 2.93**2 * RBF(length_scale=1.6) + WhiteKernel(noise_level=1e-05)
# 2.93**2 * RBF(length_scale=1.6) + WhiteKernel(noise_level=1e-05)
# 2.93**2 * RBF(length_scale=1.6) + WhiteKernel(noise_level=1e-05)
# 2.94**2 * RBF(length_scale=1.6) + WhiteKernel(noise_level=1e-05)
# 2.94**2 * RBF(length_scale=1.6) + WhiteKernel(noise_level=1e-05)
